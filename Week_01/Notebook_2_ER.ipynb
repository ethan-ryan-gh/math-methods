# %% [markdown]
# # Complex Numbers
#
# Python not only works with real numbers but also works with complex numbers. It has many use cases in mathematics. Python helps to tackle and manipulate them.
#
# Complex numbers are created from two real numbers. You can create it directly or you can use the complex function. It is written in the form of (x + yj) where x and y are real numbers and j is an imaginary number which is the square root of -1.
#
# Let’s see the syntax of the complex function:
#
#
# `complex([real[, imag]])`
#
# It consists of two arguments:
#
# **real**: It is a required input and it denotes the real part of the complex number. By default, it is 0. It can also be represented as a string like this ‘1+1j’ and in that case, the second part will be omitted.
#
# **imag**: It is an optional part and it denotes the imaginary part of the complex number. By default, it is 0.
#
# Let’s see some examples:

# %%
z = complex(5, 7)
print("Output:", z)


z = complex(3)
print("Output:", z)


z = complex()
print("Output:", z)


z = complex('1+1j')
print("Output:", z)


z = complex(1, -4)
print("Output:", z)
# Out:
# Output: (5+7j)
# Output: (3+0j)
# Output: 0j
# Output: (1+1j)
# Output: (1-4j)

# %% [markdown]
# You can also use built-in functions to access the general information. Let’s see an example:

# %%
z  = 3 + 4j

print("Real part:", z.real)
 

print("Imaginary part:", z.imag)


print("Conjugate value:", z.conjugate())
# Out:
# Real part: 3.0
# Imaginary part: 4.0
# Conjugate value: (3-4j)

# %% [markdown]
# # Arithmetic operations on Complex Numbers
#
# Like in real numbers, you can perform mathematical calculations on complex numbers such as addition, multiplication, etc. Let’s see some examples:

# %%
z1 = 6 + 7j
z2 = 1 + 4j

print("Addition of numbers:", z1 + z2)
print("Subtraction of numbers:", z1 - z2)
print("Multiplication of numbers:", z1 * z2)
print("Division of numbers:", z1 / z2)
# Out:
# Addition of numbers: (7+11j)
# Subtraction of numbers: (5+3j)
# Multiplication of numbers: (-22+31j)
# Division of numbers: (2-1j)

# %% [markdown]
# Real numbers and imaginary numbers are calculated separately.
#
# You can also perform the exponential operation with the binary operator(**) but you can’t perform it with the math module - you will need to load additional modules.
#
# **Note**: Complex numbers do not support floor division(//) and comparison operators(<, >, <=, =>).

# %% [markdown]
# ## Python cmath module functions
#
#
# The `cmath` module in python helps to use advanced mathematical functions like trigonometry, logarithmic, power and log functions, etc. You can use the math module to use these functions but only for real numbers as it does not support complex numbers. The cmath module helps to use these functions for complex numbers.
#
# The cmath module also consists of constants like `pi, e, inf, nan`, and so on that can be used in calculations. You can learn more functions and constants from the [official site](https://docs.python.org/3/library/cmath.html).
#
# Let’s see some of the functions that can be performed on the complex numbers:

# %%
import cmath

z = 4 + 2j

# Power and log functions like log2, log10, sqrt
# Power function
print("e^z:", cmath.exp(z))

# Logarithm function
print("log2(z):", cmath.log(z, 2))

# Trigonometric functions
# For sine value
print("Sine Value:", cmath.sin(z))

# For inverse sine value
print("Arc Sine Value:", cmath.asin(z))

# Hyperbolic functions
# For hyperbolic sine value
print("Hyperbolic Sine Value:", cmath.sinh(z))

# For Inverse hyperbolic sine value
print("Inverse Hyperbolic Sine Value:", cmath.asinh(z))

# For Square root of a negative number
print("Square root of -1:", cmath.sqrt(-1))
# Out:
# e^z: (-22.720847417619233+49.645957334580565j)
# log2(z): (2.1609640474436813+0.6689021062254881j)
# Sine Value: (-2.8472390868488278-2.370674169352002j)
# Arc Sine Value: (1.096921548830143+2.183585216564564j)
# Hyperbolic Sine Value: (-11.356612711218173+24.83130584894638j)
# Inverse Hyperbolic Sine Value: (2.198573027920936+0.4538702099631225j)
# Square root of -1: 1j

# %% [markdown]
# The functions that are defined in the cmath module are similar to that with the math module but they are not identical. The results that you get after using the cmath module will always be a complex number even if the value is a real number, in that case, the value of the imaginary part will be zero.

# %% [markdown]
# # Plotting Complex Numbers
#
#
# We can also plot complex numbers using matplotlib. The code below is a simple function to plot an Argand diagram. Functions are pieces of code we intend to use over and over again. Instead of typing the same lines of code multiple times, we define a function (this one is called argand) which contains the code we want to reuse. When we want to use the function, we simply use its name as a command.
#
# Please note you will have to run the cell with the function in it before you try to use the function!

# %%
def argand(a):
    import matplotlib.pyplot as plt
    import numpy as np
    
    plt.plot([0,a.real],[0,a.imag],'ro-',label='python')
    limit=np.max(np.ceil(np.absolute(a))) # set limits for axis
    plt.xlim((-limit,limit))
    plt.ylim((-limit,limit))
    plt.ylabel('Imaginary')
    plt.xlabel('Real')
    plt.show()

# %%
a = 2 + 1j
argand(a)

# %% [markdown]
# Plotting complex numbers can allow for easier comparison between them. The code cell below shows how to make a polar plot. The first command creates multiple complex numbers, with real parts 1-5, and imaginary parts 6-11. Matplotlib contains a polar plot function, so for each complex number in our list (that's what `for x in a` means), it will calculate its argument and modulus, and plot them with a dot (`marker='o') with a line from the origin.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cmath
a = np.arange(5) + 1j*np.arange(6,11)
for x in a:
    print(x)
    plt.polar([0,np.angle(x)],[0,abs(x)],marker='o')
# Out:
# 6j
# (1+7j)
# (2+8j)
# (3+9j)
# (4+10j)

# %% [markdown]
# # Plotting Hyperbolic Functions
#
# The code below takes 12 numbers evenly spaced between -pi and pi (`in_array`),so angles in radians, calculates sinh of these values (`out_array`), and plots them.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
in_array = np.linspace(-np.pi, np.pi, 12) 
out_array = np.sinh(in_array) 
  
print("in_array : ", in_array) 
print("\nout_array : ", out_array) 
  
# red for numpy.sinh() 
plt.plot(in_array, out_array, color = 'red', marker = "o") 
plt.title("numpy.sinh()") 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()
# Out:
# in_array :  [-3.14159265 -2.57039399 -1.99919533 -1.42799666 -0.856798   -0.28559933
#   0.28559933  0.856798    1.42799666  1.99919533  2.57039399  3.14159265]
#
# out_array :  [-11.54873936  -6.49723393  -3.62383424  -1.9652737   -0.96554336
#   -0.28949778   0.28949778   0.96554336   1.9652737    3.62383424
#    6.49723393  11.54873936]

# %% [markdown]
# Congratulations! You can now use Python to perform arithmetic with complex numbers, and also create plots!

# %% [markdown]
# # References
#
# https://www.python-engineer.com/posts/complex-numbers-python/
#
# https://stackoverflow.com/questions/17445720/how-to-plot-complex-numbers-argand-diagram-using-matplotlib
#
# https://www.geeksforgeeks.org/numpy-sinh-python/

# %% [markdown]
# # Homework
#
# Please work on the questions below in class and complete for homework. You can include your answers in this notebook, or submit them, via Canvas, as a separate pdf.

# %% [markdown]
# ## Research
#
# 1) Briefly describe (2-3 sentences) a physics problem which uses complex numbers. This could be an equation which specificlly uses complex numbers, or one which will give a complex number as an answer.
#
# Well being in quantum I do feel obligated to mention that as my problem example. The quantum number spin is complex in the y-direction (in hillbert space) because of a reason I don't understand, but it leads to using complex numbers when solving the wave function. Complex numbers are necessary and required when working with a dimension that is not is "real" space.
#
# 2) Briefly describe a physics problem which uses hyperbolic functions. This could be an equation which specificlly uses sinh or cosh, or one which will gives one of these as an answer.
#
# Hyperbolic functions are commonly used in cross-sections in atomic and particle physics. Due to the shape that the incoming particle makes when colliding with the heavier subject, such as an atom, the collissions can be graphed hyperbolically. This also works similarly with planets and their orbits, specifically comets, which can have a hyperbolic-like orbit.

# %% [markdown]
# ## Calculations
#
# Complete questions from the textbook
